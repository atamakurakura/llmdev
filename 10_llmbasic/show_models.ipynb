# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデルの一覧を取得
models = client.models.list()

# モデルの一覧を表示
for model in models:
  print(model.id)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[3], line 13
#      10 client = OpenAI(api_key=os.environ['API_KEY'])
#      12 # モデルの一覧を取得
# ---> 13 models = client.models.list()
#      15 # モデルの一覧を表示
#      16 for model in models:
#
# File ~/team-training2/llmdev/.venv/lib/python3.12/site-packages/openai/resources/models.py:91, in Models.list(self, extra_headers, extra_query, extra_body, timeout)
#      77 def list(
#      78     self,
#      79     *,
#    (...)     85     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#      86 ) -> SyncPage[Model]:
#      87     """
#      88     Lists the currently available models, and provides basic information about each
#      89     one such as the owner and availability.
#      90     """
# ---> 91     return self._get_api_list(
#      92         "/models",
#      93         page=SyncPage[Model],
#      94         options=make_request_options(
#      95             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#      96         ),
#      97         model=Model,
#      98     )
#
# File ~/team-training2/llmdev/.venv/lib/python3.12/site-packages/openai/_base_client.py:1327, in SyncAPIClient.get_api_list(self, path, model, page, body, options, method)
#    1316 def get_api_list(
#    1317     self,
#    1318     path: str,
#    (...)   1324     method: str = "get",
#    1325 ) -> SyncPageT:
#    1326     opts = FinalRequestOptions.construct(method=method, url=path, json_data=body, **options)
# -> 1327     return self._request_api_list(model, page, opts)
#
# File ~/team-training2/llmdev/.venv/lib/python3.12/site-packages/openai/_base_client.py:1178, in SyncAPIClient._request_api_list(self, model, page, options)
#    1174     return resp
#    1176 options.post_parser = _parser
# -> 1178 return self.request(page, options, stream=False)
#
# File ~/team-training2/llmdev/.venv/lib/python3.12/site-packages/openai/_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     952 else:
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File ~/team-training2/llmdev/.venv/lib/python3.12/site-packages/openai/_base_client.py:981, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     978 options = self._prepare_options(options)
#     980 remaining_retries = options.get_max_retries(self.max_retries) - retries_taken
# --> 981 request = self._build_request(options, retries_taken=retries_taken)
#     982 self._prepare_request(request)
#     984 kwargs: HttpxSendArgs = {}
#
# File ~/team-training2/llmdev/.venv/lib/python3.12/site-packages/openai/_base_client.py:466, in BaseClient._build_request(self, options, retries_taken)
#     463     else:
#     464         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 466 headers = self._build_headers(options, retries_taken=retries_taken)
#     467 params = _merge_mappings(self.default_query, options.params)
#     468 content_type = headers.get("Content-Type")
#
# File ~/team-training2/llmdev/.venv/lib/python3.12/site-packages/openai/_base_client.py:417, in BaseClient._build_headers(self, options, retries_taken)
#     414 self._validate_headers(headers_dict, custom_headers)
#     416 # headers are case-insensitive while dictionaries are not.
# --> 417 headers = httpx.Headers(headers_dict)
#     419 idempotency_header = self._idempotency_header
#     420 if idempotency_header and options.method.lower() != "get" and idempotency_header not in headers:
#
# File ~/team-training2/llmdev/.venv/lib/python3.12/site-packages/httpx/_models.py:78, in Headers.__init__(self, headers, encoding)
#      72     self._list = list(headers._list)
#      73 elif isinstance(headers, Mapping):
#      74     self._list = [
#      75         (
#      76             normalize_header_key(k, lower=False, encoding=encoding),
#      77             normalize_header_key(k, lower=True, encoding=encoding),
# ---> 78             normalize_header_value(v, encoding),
#      79         )
#      80         for k, v in headers.items()
#      81     ]
#      82 else:
#      83     self._list = [
#      84         (
#      85             normalize_header_key(k, lower=False, encoding=encoding),
#    (...)     89         for k, v in headers
#      90     ]
#
# File ~/team-training2/llmdev/.venv/lib/python3.12/site-packages/httpx/_utils.py:53, in normalize_header_value(value, encoding)
#      51 if isinstance(value, bytes):
#      52     return value
# ---> 53 return value.encode(encoding or "ascii")
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 8-11: ordinal not in range(128)
